# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
x = np.linspace(-10,10,100)
y = np.empty_like(x)

# %%
# Sigmoid Function
def sigmoid(x:np.ndarray):
    y = np.empty_like(x)

    y = 1/(1+np.exp(-x))

    return y

# %%
plt.grid(linewidth=0.3)
plt.plot(x,sigmoid(x))

plt.title("Función Sigmoide")
# Out:
# Text(0.5, 1.0, 'Función Sigmoide')

# %%
#tanh
plt.plot(x,np.tanh(x))
plt.grid(linewidth=0.3)
plt.title("Función tanh")
# Out:
# Text(0.5, 1.0, 'Función tanh')

# %%
#ReLU
plt.plot(x,np.maximum(np.zeros_like(x),x))
plt.grid(linewidth=0.3)
plt.title("Función ReLU")
# Out:
# Text(0.5, 1.0, 'Función ReLU')

# %%
import scipy
a = np.arange(-2,2,1)
z = np.random.normal(0,1.5,*a.shape)


plt.bar(a,scipy.special.softmax(z),0.9)
# Out:
# <BarContainer object of 4 artists>
